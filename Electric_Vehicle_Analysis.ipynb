# %% [markdown]
# # Predictive Analysis of the European Electric Vehicle Market: Infrastructure & Performance Trends

# %% [markdown]
# ## About the Dataset
#
# **Context:**
# This dataset provides a comprehensive overview of the Electric Vehicle (EV) market in Germany. It captures technical specifications, performance metrics, and current market pricing for a wide variety of EV models from global manufacturers like Tesla, BMW, BYD, and Volkswagen.
#
# **Purpose:**
# The dataset is designed to help analysts understand the relationship between battery technology, vehicle performance (range and acceleration), and market value. It serves as a basis for predictive modeling regarding EV pricing and consumer adoption trends within the European "Energiewende" (Energy Transition) framework.
#
# **Dataset Features:**
# The dataset contains several key parameters essential for automotive and energy sector analysis:
#
# **Battery**: Useable battery capacity (in kWh).
#
# **Efficiency**: Energy consumption (in Wh/km).
#
# **Fast Charge**: Fast charging speed (in km/h).
#
# **Price.DE**: Current market price in Germany (in Euro). Includes "NA" values for data cleaning practice.
#
# **Range**: Maximum travel distance on a single charge (in km).
#
# **Top Speed**: Maximum vehicle speed (in km/h).
#
# **Acceleration** (0-100): Time taken to reach 100 km/h (in seconds).
#
# **Car Name & Link**: Categorical strings identifying the model and source data.
#
# ### Dataset Scope
#
# The dataset is specifically curated from a German market perspective, making it highly relevant for applications to German universities or automotive firms.
#
# The data reflects the diverse landscape of the EV industry—from budget-friendly city cars (like the Dacia Spring) to ultra-luxury performance models (like the Rolls-Royce Spectre). This variety allows for a nuanced exploration of how different segments of the market prioritize efficiency versus performance.
#
# ### Feature Engineering Opportunity:
#
# **Price per Range**: A derived metric to calculate the value-for-money ratio of different models.
#
# **Charging Efficiency**: A derived metric combining Battery size and Fast Charge speed to determine long-distance travel viability.

# %% [markdown]
# ## Acknowledgements & Citation
#
# **Acknowledgements**:
# This dataset is a curated collection of Electric Vehicle (EV) technical specifications and market pricing. It was originally scraped from the EV Database and organized by Fatih İlhan on Kaggle to facilitate comparative automotive analysis.
#
# **Inspiration**:
# The project was developed to analyze the efficiency-to-price ratio within the German automotive market. By examining variables like battery capacity and range, the goal is to identify which manufacturers are leading the transition toward sustainable transport in Europe.
#
# **Citation**:
# If you use this dataset in your research or projects, please cite the Kaggle repository:
# İlhan, F. (2024). Electric Vehicle Specifications and Prices. Kaggle. https://www.kaggle.com/datasets/fatihilhan/electric-vehicle-specifications-and-prices
#
# **Thanks**:
# Special thanks to Fatih İlhan for providing a machine-learning-ready version of this data, and to the EV Database for maintaining the original technical records. This dataset allows for critical exploration of the performance bottlenecks currently facing the EV industry.

# %%
import pandas as pd

# Load the EV dataset from GitHub
ev_df = pd.read_csv("https://raw.githubusercontent.com/divyadas176/Electric_Vehicle_Analysis/main/EV_cars.csv")

# Display first 5 rows to check data
ev_df.head()
# Out:
#    Battery                             Car_name  \
# 0     75.0  Tesla Model Y Long Range Dual Motor
# 1     57.5                        Tesla Model 3
# 2     60.5                           BYD ATTO 3
# 3     61.7               MG MG4 Electric 64 kWh
# 4     75.0  Tesla Model 3 Long Range Dual Motor
#
#                                        Car_name_link  Efficiency  Fast_charge  \
# 0  https://ev-database.org/car/1619/Tesla-Model-Y...         172        670.0
# 1     https://ev-database.org/car/1991/Tesla-Model-3         137        700.0
# 2        https://ev-database.org/car/1782/BYD-ATTO-3         183        370.0
# 3  https://ev-database.org/car/1708/MG-MG4-Electr...         171        630.0
# 4  https://ev-database.org/car/1992/Tesla-Model-3...         149        780.0
#
#    Price.DE.  Range  Top_speed  acceleration..0.100.
# 0    59017.0    435        217                   5.0
# 1    46220.0    420        201                   6.1
# 2    44625.0    330        160                   7.3
# 3    39990.0    360        160                   7.9
# 4    55220.0    505        201                   4.4

# %%
# Check the number of rows and columns in the EV dataset

ev_df.shape
# Out:
# (360, 9)

# %%
# view full dataset

ev_df
# Out:
#      Battery                             Car_name  \
# 0       75.0  Tesla Model Y Long Range Dual Motor
# 1       57.5                        Tesla Model 3
# 2       60.5                           BYD ATTO 3
# 3       61.7               MG MG4 Electric 64 kWh
# 4       75.0  Tesla Model 3 Long Range Dual Motor
# ..       ...                                  ...
# 355     46.3      Citroen e-Jumpy Combi XL 50 kWh
# 356     46.3              Fiat E-Ulysse L2 50 kWh
# 357     46.3         Opel Vivaro-e Combi L 50 kWh
# 358     68.0          Opel Zafira-e Life M 75 kWh
# 359     46.3              Fiat E-Ulysse L3 50 kWh
#
#                                          Car_name_link  Efficiency  \
# 0    https://ev-database.org/car/1619/Tesla-Model-Y...         172
# 1       https://ev-database.org/car/1991/Tesla-Model-3         137
# 2          https://ev-database.org/car/1782/BYD-ATTO-3         183
# 3    https://ev-database.org/car/1708/MG-MG4-Electr...         171
# 4    https://ev-database.org/car/1992/Tesla-Model-3...         149
# ..                                                 ...         ...
# 355  https://ev-database.org/car/1596/Citroen-e-Jum...         257
# 356  https://ev-database.org/car/1721/Fiat-E-Ulysse...         250
# 357  https://ev-database.org/car/1601/Opel-Vivaro-e...         257
# 358  https://ev-database.org/car/1348/Opel-Zafira-e...         257
# 359  https://ev-database.org/car/1723/Fiat-E-Ulysse...         257
#
#      Fast_charge  Price.DE.  Range  Top_speed  acceleration..0.100.
# 0          670.0    59017.0    435        217                   5.0
# 1          700.0    46220.0    420        201                   6.1
# 2          370.0    44625.0    330        160                   7.3
# 3          630.0    39990.0    360        160                   7.9
# 4          780.0    55220.0    505        201                   4.4
# ..           ...        ...    ...        ...                   ...
# 355        290.0    52730.0    180        130                  12.1
# 356        290.0    55990.0    185        130                  12.1
# 357        290.0    51825.0    180        130                  12.1
# 358        290.0    69250.0    265        130                  13.3
# 359        290.0    56990.0    180        130                  12.1
#
# [360 rows x 9 columns]

# %%
# Get summary information about the DataFrame:
# - Column names
# - Data types
# - Number of non-null values
# This helps identify missing values and understand the dataset structure

ev_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 360 entries, 0 to 359
# Data columns (total 9 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Battery               360 non-null    float64
#  1   Car_name              360 non-null    object
#  2   Car_name_link         360 non-null    object
#  3   Efficiency            360 non-null    int64
#  4   Fast_charge           358 non-null    float64
#  5   Price.DE.             309 non-null    float64
#  6   Range                 360 non-null    int64
#  7   Top_speed             360 non-null    int64
#  8   acceleration..0.100.  360 non-null    float64
# dtypes: float64(4), int64(3), object(2)
# memory usage: 25.4+ KB

# %%
# Get statistical summary of all numeric columns in the dataset:
# - Count, mean, standard deviation
# - Minimum and maximum values
# - 25th, 50th (median), and 75th percentiles

ev_df.describe()
# Out:
#           Battery  Efficiency  Fast_charge      Price.DE.       Range  \
# count  360.000000  360.000000   358.000000     309.000000  360.000000
# mean    71.187500  195.175000   552.960894   67264.284790  369.694444
# std     20.389849   31.909429   236.864801   34508.249544  107.315514
# min     21.300000  137.000000   170.000000   22550.000000  135.000000
# 25%     57.500000  171.000000   360.000000   45690.000000  295.000000
# 50%     71.000000  188.000000   520.000000   56942.000000  380.000000
# 75%     85.000000  208.250000   680.000000   73100.000000  446.250000
# max    123.000000  295.000000  1290.000000  218000.000000  685.000000
#
#         Top_speed  acceleration..0.100.
# count  360.000000            360.000000
# mean   180.919444              7.288889
# std     36.232023              3.005897
# min    125.000000              2.100000
# 25%    155.750000              4.900000
# 50%    180.000000              6.750000
# 75%    200.000000              9.000000
# max    320.000000             19.100000

# %% [markdown]
# ## Data Cleaning and Preprocessing

# %%
# Dropping the link column as it is not required for statistical analysis

ev_df.drop(columns=['Car_name_link'], inplace=True)

# %%
ev_df.tail()
# Out:
#      Battery                         Car_name  Efficiency  Fast_charge  \
# 355     46.3  Citroen e-Jumpy Combi XL 50 kWh         257        290.0
# 356     46.3          Fiat E-Ulysse L2 50 kWh         250        290.0
# 357     46.3     Opel Vivaro-e Combi L 50 kWh         257        290.0
# 358     68.0      Opel Zafira-e Life M 75 kWh         257        290.0
# 359     46.3          Fiat E-Ulysse L3 50 kWh         257        290.0
#
#      Price.DE.  Range  Top_speed  acceleration..0.100.
# 355    52730.0    180        130                  12.1
# 356    55990.0    185        130                  12.1
# 357    51825.0    180        130                  12.1
# 358    69250.0    265        130                  13.3
# 359    56990.0    180        130                  12.1

# %%
# Renaming specific columns

ev_df.rename(columns={
    'Price.DE.': 'Price_DE',
    'acceleration..0.100.': 'Acceleration_0_100'
}, inplace=True)

# %%
ev_df.tail()
# Out:
#      Battery                         Car_name  Efficiency  Fast_charge  \
# 355     46.3  Citroen e-Jumpy Combi XL 50 kWh         257        290.0
# 356     46.3          Fiat E-Ulysse L2 50 kWh         250        290.0
# 357     46.3     Opel Vivaro-e Combi L 50 kWh         257        290.0
# 358     68.0      Opel Zafira-e Life M 75 kWh         257        290.0
# 359     46.3          Fiat E-Ulysse L3 50 kWh         257        290.0
#
#      Price_DE  Range  Top_speed  Acceleration_0_100
# 355   52730.0    180        130                12.1
# 356   55990.0    185        130                12.1
# 357   51825.0    180        130                12.1
# 358   69250.0    265        130                13.3
# 359   56990.0    180        130                12.1

# %%
# Returns the count of NaN values for each column

ev_df.isnull().sum()
# Out:
# Battery                0
# Car_name               0
# Efficiency             0
# Fast_charge            2
# Price_DE              51
# Range                  0
# Top_speed              0
# Acceleration_0_100     0
# dtype: int64

# %%
# Filling Fast_charge with the overall median

ev_df['Fast_charge'] = ev_df['Fast_charge'].fillna(ev_df['Fast_charge'].median())

# %%
ev_df.isnull().sum()
# Out:
# Battery                0
# Car_name               0
# Efficiency             0
# Fast_charge            0
# Price_DE              51
# Range                  0
# Top_speed              0
# Acceleration_0_100     0
# dtype: int64

# %%
# Create the 'Manufacturer' column by taking the first word of 'Car_name'
ev_df['Manufacturer'] = ev_df['Car_name'].str.split().str[0]

# Check the first few rows to confirm it worked
ev_df[['Car_name', 'Manufacturer']].head()
# Out:
#                               Car_name Manufacturer
# 0  Tesla Model Y Long Range Dual Motor        Tesla
# 1                        Tesla Model 3        Tesla
# 2                           BYD ATTO 3          BYD
# 3               MG MG4 Electric 64 kWh           MG
# 4  Tesla Model 3 Long Range Dual Motor        Tesla

# %%
# Filling Price_DE using two-tier imputation strategy

# Tier 1: Brand-Specific Imputation (High Accuracy)
# We fill NaNs using the median price of other cars from the same Manufacturer
brand_medians = ev_df.groupby('Manufacturer')['Price_DE'].transform('median')
ev_df['Price_DE'] = ev_df['Price_DE'].fillna(brand_medians)

# Tier 2: Global Median Fallback (Full Coverage)
# If a brand only has one car and its price is missing, Tier 1 won't work.
# This line catches any remaining NaNs using the overall dataset median.
ev_df['Price_DE'] = ev_df['Price_DE'].fillna(ev_df['Price_DE'].median())

# %%
ev_df.isnull().sum()
# Out:
# Battery               0
# Car_name              0
# Efficiency            0
# Fast_charge           0
# Price_DE              0
# Range                 0
# Top_speed             0
# Acceleration_0_100    0
# Manufacturer          0
# dtype: int64

# %%
ev_df
# Out:
#      Battery                             Car_name  Efficiency  Fast_charge  \
# 0       75.0  Tesla Model Y Long Range Dual Motor         172        670.0
# 1       57.5                        Tesla Model 3         137        700.0
# 2       60.5                           BYD ATTO 3         183        370.0
# 3       61.7               MG MG4 Electric 64 kWh         171        630.0
# 4       75.0  Tesla Model 3 Long Range Dual Motor         149        780.0
# ..       ...                                  ...         ...          ...
# 355     46.3      Citroen e-Jumpy Combi XL 50 kWh         257        290.0
# 356     46.3              Fiat E-Ulysse L2 50 kWh         250        290.0
# 357     46.3         Opel Vivaro-e Combi L 50 kWh         257        290.0
# 358     68.0          Opel Zafira-e Life M 75 kWh         257        290.0
# 359     46.3              Fiat E-Ulysse L3 50 kWh         257        290.0
#
#      Price_DE  Range  Top_speed  Acceleration_0_100 Manufacturer
# 0     59017.0    435        217                 5.0        Tesla
# 1     46220.0    420        201                 6.1        Tesla
# 2     44625.0    330        160                 7.3          BYD
# 3     39990.0    360        160                 7.9           MG
# 4     55220.0    505        201                 4.4        Tesla
# ..        ...    ...        ...                 ...          ...
# 355   52730.0    180        130                12.1      Citroen
# 356   55990.0    185        130                12.1         Fiat
# 357   51825.0    180        130                12.1         Opel
# 358   69250.0    265        130                13.3         Opel
# 359   56990.0    180        130                12.1         Fiat
#
# [360 rows x 9 columns]

# %%
ev_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 360 entries, 0 to 359
# Data columns (total 9 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Battery             360 non-null    float64
#  1   Car_name            360 non-null    object
#  2   Efficiency          360 non-null    int64
#  3   Fast_charge         360 non-null    float64
#  4   Price_DE            360 non-null    float64
#  5   Range               360 non-null    int64
#  6   Top_speed           360 non-null    int64
#  7   Acceleration_0_100  360 non-null    float64
#  8   Manufacturer        360 non-null    object
# dtypes: float64(4), int64(3), object(2)
# memory usage: 25.4+ KB

# %%
# Standardizing all numeric columns to float64

ev_df['Efficiency'] = ev_df['Efficiency'].astype(float)
ev_df['Range'] = ev_df['Range'].astype(float)
ev_df['Top_speed'] = ev_df['Top_speed'].astype(float)

# %%
ev_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 360 entries, 0 to 359
# Data columns (total 9 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Battery             360 non-null    float64
#  1   Car_name            360 non-null    object
#  2   Efficiency          360 non-null    float64
#  3   Fast_charge         360 non-null    float64
#  4   Price_DE            360 non-null    float64
#  5   Range               360 non-null    float64
#  6   Top_speed           360 non-null    float64
#  7   Acceleration_0_100  360 non-null    float64
#  8   Manufacturer        360 non-null    object
# dtypes: float64(7), object(2)
# memory usage: 25.4+ KB

# %%
# Outlier Detection using Box Plot

import seaborn as sns
import matplotlib.pyplot as plt

# Visualizing Price outliers
sns.boxplot(x=ev_df['Price_DE'])
plt.title('Checking for Price Outliers')
plt.show()

# %% [markdown]
# Individual circles on the right side (beyond €110,000) means your dataset includes both "mass-market" cars and "luxury/hyper" EVs.
# Here is the interpretation:
#
# * The Median (The middle line in the blue box): Most EVs in the dataset are priced around €55,000 to €60,000.
# * The "Whiskers" (The lines extending from the box): The typical price range for a standard EV is roughly between €20,000 and €110,000.
# * The Outliers (The circles on the right): Any car priced above €115,000 is considered a statistical outlier. This likely includes high-performance models like the Porsche Taycan, Audi e-tron GT, or top-tier Teslas.

# %%
ev_df
# Out:
#      Battery                             Car_name  Efficiency  Fast_charge  \
# 0       75.0  Tesla Model Y Long Range Dual Motor       172.0        670.0
# 1       57.5                        Tesla Model 3       137.0        700.0
# 2       60.5                           BYD ATTO 3       183.0        370.0
# 3       61.7               MG MG4 Electric 64 kWh       171.0        630.0
# 4       75.0  Tesla Model 3 Long Range Dual Motor       149.0        780.0
# ..       ...                                  ...         ...          ...
# 355     46.3      Citroen e-Jumpy Combi XL 50 kWh       257.0        290.0
# 356     46.3              Fiat E-Ulysse L2 50 kWh       250.0        290.0
# 357     46.3         Opel Vivaro-e Combi L 50 kWh       257.0        290.0
# 358     68.0          Opel Zafira-e Life M 75 kWh       257.0        290.0
# 359     46.3              Fiat E-Ulysse L3 50 kWh       257.0        290.0
#
#      Price_DE  Range  Top_speed  Acceleration_0_100 Manufacturer
# 0     59017.0  435.0      217.0                 5.0        Tesla
# 1     46220.0  420.0      201.0                 6.1        Tesla
# 2     44625.0  330.0      160.0                 7.3          BYD
# 3     39990.0  360.0      160.0                 7.9           MG
# 4     55220.0  505.0      201.0                 4.4        Tesla
# ..        ...    ...        ...                 ...          ...
# 355   52730.0  180.0      130.0                12.1      Citroen
# 356   55990.0  185.0      130.0                12.1         Fiat
# 357   51825.0  180.0      130.0                12.1         Opel
# 358   69250.0  265.0      130.0                13.3         Opel
# 359   56990.0  180.0      130.0                12.1         Fiat
#
# [360 rows x 9 columns]

# %% [markdown]
# ## Feature Engineering

# %%
# Create a 'Price_per_km' column
#Since analyzing the European market, creating a "Value for Money" metric. This shows how many Euros you pay for every 1 km of range.

ev_df['Price_per_km'] = ev_df['Price_DE'] / ev_df['Range']

# %%
ev_df.sample(10)
# Out:
#      Battery                             Car_name  Efficiency  Fast_charge  \
# 4       75.0  Tesla Model 3 Long Range Dual Motor       149.0        780.0
# 188     66.5              Mercedes EQA 350 4MATIC       187.0        510.0
# 293     21.3                 Fiat 500e 3+1 24 kWh       158.0        230.0
# 303     68.0       Citroen e-Jumpy Combi M 75 kWh       257.0        290.0
# 251     74.0       Genesis GV70 Electrified Sport       211.0        860.0
# 97      84.0                         Maxus MIFA 9       230.0        330.0
# 355     46.3      Citroen e-Jumpy Combi XL 50 kWh       257.0        290.0
# 150     90.0                Mercedes EQV 300 Long       290.0        310.0
# 131    112.0              Lucid Air Grand Touring       168.0        840.0
# 39      50.8               MG MG4 Electric 51 kWh       169.0        390.0
#
#      Price_DE  Range  Top_speed  Acceleration_0_100 Manufacturer  Price_per_km
# 4     55220.0  505.0      201.0                 4.4        Tesla    109.346535
# 188   56424.0  355.0      160.0                 6.0     Mercedes    158.940845
# 293   37490.0  135.0      135.0                 9.0         Fiat    277.703704
# 303   57940.0  265.0      130.0                13.3      Citroen    218.641509
# 251   67300.0  350.0      235.0                 4.2      Genesis    192.285714
# 97    68990.0  365.0      180.0                 9.2        Maxus    189.013699
# 355   52730.0  180.0      130.0                12.1      Citroen    292.944444
# 150   71626.0  310.0      160.0                12.1     Mercedes    231.051613
# 131  159000.0  665.0      270.0                 3.0        Lucid    239.097744
# 39    34990.0  300.0      160.0                 7.7           MG    116.633333

# %%
# Check if there are duplicate rows

ev_df.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# ## Exploratory Data Analysis (EDA)
